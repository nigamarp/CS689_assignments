# %% [markdown]
# Loading Test Files

# %%
with open('/kaggle/input/english-hindi/test.en','r') as f:
    en=f.readlines()

# %%
with open('/kaggle/input/english-hindi/test.hi','r') as f:
    hi=f.readlines()

# %%
with open('/kaggle/input/marathi/test.mr','r') as f:
    mr=f.readlines()

# %% [markdown]
# Selecting Random sentences

# %%
import random
random_index=[]
while(len(random_index)<1000):
    temp=random.randint(1, 2389)
    if temp not in random_index:
        random_index.append(temp)
random_en=[]
random_hi=[]
random_mr=[]
for i in range(1000):
    random_en.append(en[random_index[i]])
    random_hi.append(hi[random_index[i]])
    random_mr.append(mr[random_index[i]])

# %%
print(random_mr[40:50])
# Out:
# ['आज वीर सावरकर यांची जयंती आहे.\n', 'या सुविधांमुळे पर्यटकांचा ओघ वाढेल असे पंतप्रधान म्हणाले.\n', 'अशा काही सुधारणांमुळे आमची अर्थव्यवस्था विकासाच्या मार्गावर वेगाने घोडदौड करत आहे.\n', 'या मोहिमेअंतर्गत 32 हजाराहून अधिक सणांचे निदान झाले आणि त्यानंतर औषधोपचार सुरू झाले.\n', 'या सगळ्या महापुरूषांचा एक केंद्र-बिंदू कोणता होता?\n', 'ही गोष्ट खरी आहे की, राजकीय पक्षांनी वेळोवेळी व्यवस्थेत सुधारणा करण्याचे प्रयत्न केलेत, सर्व पक्षांनी एकत्र येत स्वतःहून स्वतःवर बंधने स्वीकारली आहेत.\n', 'सरदार वल्लभभाई पटेल यांच्या जयंतीचे औचित्य साधून 182 मीटर उंचीच्या या पुतळ्याचे गुजरातमधल्या नर्मदा जिल्ह्यातल्या केवडिया येथे लोकार्पण करण्यात येणार आहे.\n', 'केंद्र सरकार आणि सर्व राज्ये तसेच राजकीय पक्षांच्या सहकार्यामुळे हे शक्य झाले आहे.\n', '153 मीटर उंची असलेली ही गॅलरी एका वेळी 200 पाहुण्यांना सामावून घेऊ शकते.\n', 'तुमच्या पिढीला देखील खूप त्रास सहन करावा लागला.\n']

# %%
with open('random_indexes.txt', "w") as file:
    for index in random_index:
        file.write(f"{index}\n")
print(random_en[1])
print(random_hi[1])

# %%
with open('/kaggle/input/random-index/random_indexes.txt','r') as f:
    random_index=f.readlines()
for i in range(1000):
        random_index[i]=int(random_index[i])
# print(random_index)

# %% [markdown]
# NLLB

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")
trans_hi=[]
# article = "UN Chief says there is no military solution in Syria"
with open('trans_hi.txt', "w") as file:
    for i in range(1000):
        inputs = tokenizer(random_en[i], return_tensors="pt")
        translated_tokens = model.generate(
            **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["hin_Deva"], max_length=30
        )
        temp=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
        trans_hi.append(temp)
        file.write(temp + "\n")

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "facebook/nllb-200-distilled-600M", token='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', src_lang="hin_Deva"
)
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M", token='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')

with open('trans_en.txt', "w") as file:
    for i in range(1000):
        inputs = tokenizer(random_en[i], return_tensors="pt")
        translated_tokens = model.generate(
            **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"], max_length=30
        )
        temp=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
        trans_hi.append(temp)
        file.write(temp + "\n")

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "facebook/nllb-200-distilled-600M", token='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', src_lang="hin_Deva"
)
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M", token='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')

with open('trans_mr.txt', "w") as file:
    for i in range(1000):
        inputs = tokenizer(random_hi[i], return_tensors="pt")
        translated_tokens = model.generate(
            **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["mar_Deva"], max_length=30
        )
        temp=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
        trans_hi.append(temp)
        file.write(temp + "\n")

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "facebook/nllb-200-distilled-600M", token='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', src_lang="mar_Deva"
)
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M", token='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')

with open('trans_mr_hi.txt', "w") as file:
    for i in range(1000):
        inputs = tokenizer(random_mr[i], return_tensors="pt")
        translated_tokens = model.generate(
            **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["hin_Deva"], max_length=30
        )
        temp=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
        trans_hi.append(temp)
        file.write(temp + "\n")

# %% [markdown]
# ROUGE and BLEU SCORES

# %%
# !pip install Rouge
# !pip install nltk

# %% [markdown]
# Rouge Score and BLEU score for hi to en(NLLB)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/candidate/trans_en.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_en[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_en[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.8563181223359778, 'p': 0.9592697005436942, 'f': 0.9022997408532768}, 'rouge-2': {'r': 0.8096408451235859, 'p': 0.9122373508918804, 'f': 0.8549250840869359}, 'rouge-l': {'r': 0.8532070112248666, 'p': 0.9558710077332367, 'f': 0.8990516205525249}}
# BLEU Score: 0.8715531161738905

# %% [markdown]
# Rouge and BLEU score for en to hi(NLLB)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/candidate/trans_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_hi[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5565642655418198, 'p': 0.602942814289254, 'f': 0.5740234966932278}, 'rouge-2': {'r': 0.3260472841936275, 'p': 0.3547966832639399, 'f': 0.33659658565724726}, 'rouge-l': {'r': 0.5314342668855052, 'p': 0.5730108068574014, 'f': 0.5470424433490271}}
# BLEU Score: 0.5920992892141832

# %% [markdown]
# Rouge and BLEU score for hi to mr(NLLB)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/candidate/trans_mr.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_mr[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_mr[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5087065789387771, 'p': 0.6172917637917638, 'f': 0.5547186736809223}, 'rouge-2': {'r': 0.3036916951297757, 'p': 0.3742444222444221, 'f': 0.3332664449073795}, 'rouge-l': {'r': 0.500629655861854, 'p': 0.6073195415695416, 'f': 0.5458062391418893}}
# BLEU Score: 0.6907100593266013

# %% [markdown]
# Rouge and BLEU score for mr to hi(NLLB)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/candidate/trans_mr_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_hi[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5015991056587034, 'p': 0.5415249856782366, 'f': 0.5166695821010113}, 'rouge-2': {'r': 0.2646612798528382, 'p': 0.28424640895739955, 'f': 0.27140919259856483}, 'rouge-l': {'r': 0.4762999895701134, 'p': 0.5116163783756663, 'f': 0.4894846349648258}}
# BLEU Score: 0.5283936536693399

# %% [markdown]
# INDICTRANS

# %%
# %cd /kaggle/working/
# !git clone https://github.com/VarunGumma/IndicTransTokenizer
# %cd /kaggle/working/IndicTransTokenizer
# Out:
# /kaggle/working
# Cloning into 'IndicTransTokenizer'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 123 (delta 52), reused 94 (delta 31), pack-reused 0
# Receiving objects: 100% (123/123), 3.85 MiB | 14.10 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /kaggle/working/IndicTransTokenizer

# %%
pip install --editable ./
# Out:
# Obtaining file:///kaggle/working/IndicTransTokenizer
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/VarunGumma/indic_nlp_library to /tmp/pip-install-4m6m1xta/indic-nlp-library-it2_e7ab38a59897479b9900bc01fc4ac716
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library /tmp/pip-install-4m6m1xta/indic-nlp-library-it2_e7ab38a59897479b9900bc01fc4ac716
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 09d30a15286cc252a12682e5450c807379717eaf
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 886.6 kB/s eta 0:00:00:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 1.9 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 5.9 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 14.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# %%
tokenizer = IndicTransTokenizer(direction="en-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/61.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# Initialize tokenizer, processor, and model
tokenizer = IndicTransTokenizer(direction="en-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)

# Read input sentences from a file
# input_file = "benchmarks/benchmarks/wat2021-devtest/dev.en" 
output_file = "indictrans_hi.txt"  # Update with the desired output file path

# with open(input_file, "r", encoding="utf-8") as file:
#     sentences = file.readlines()

# Preprocess the batch
batch = ip.preprocess_batch(random_en, src_lang="eng_Latn", tgt_lang="hin_Deva")
batch = tokenizer(batch, src=True, return_tensors="pt")

# Generate translations
with torch.inference_mode():
    outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

# Decode and postprocess the translations
outputs = tokenizer.batch_decode(outputs, src=False)
outputs = ip.postprocess_batch(outputs, lang="hin_Deva")

# Write translations to output file
with open(output_file, "w", encoding="utf-8") as file:
    for translation in outputs:
        file.write(translation + "\n")

print(f"Translations written to {output_file}.")
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/61.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# Initialize tokenizer, processor, and model
tokenizer = IndicTransTokenizer(direction="en-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)

# Read input sentences from a file in batches
input_file = "benchmarks/benchmarks/wat2021-devtest/dev.en" 
output_file = "indictrans_hi.txt"  # Update with the desired output file path

# Define batch size
batch_size = 8

# with open(input_file, "r", encoding="utf-8") as file:
#     sentences = file.readlines()
sentences=random_en
# Process and translate sentences in batches
with open(output_file, "w", encoding="utf-8") as file:
    for i in range(0, len(sentences), batch_size):
        batch_sentences = sentences[i:i+batch_size]
        
        # Preprocess the batch
        batch = ip.preprocess_batch(batch_sentences, src_lang="eng_Latn", tgt_lang="hin_Deva")
        batch = tokenizer(batch, src=True, return_tensors="pt")

        # Generate translations
        with torch.inference_mode():
            outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

        # Decode and postprocess the translations
        translations = tokenizer.batch_decode(outputs, src=False)
        translations = ip.postprocess_batch(translations, lang="hin_Deva")

        # Write translations to output file
        for translation in translations:
            file.write(translation + "\n")
            print(translation)
# Out:
# इसी क्रांति मंदिर में एक दृश्य कला संग्रहालय की स्थापना की गई है।
# प्रधानमंत्री श्री नरेन्द्र मोदी की अध्यक्षता में केंद्रीय मंत्रिमंडल ने पारस्परिक सहयोग के संबंध में यूरोपीय प्रतिभूति और बाजार प्राधिकरण (एस्मा) के साथ समझौता ज्ञापन (एमओयू) करने के लिए भारतीय प्रतिभूति और विनिमय बोर्ड (एस. ई. बी. आई.) को अपनी मंजूरी दे दी है।
# अन्य देशों के उपभोक्ताओं से संबंधित मामलों में तेजी से कार्य करने के लिए सहयोग के लिए एक रूपरेखा भी आवश्यक है।
# हमने वर्ष 2022 तक 175 गीगावाट अक्षय ऊर्जा की क्षमता का निर्माण करने का लक्ष्य रखा है।
# आज हमारी मौद्रिक नीति, स्टार्ट अप इंडिया, स्टैंड अप इंडिया पहल हमारे युवा नवोन्मेषकों और युवा उद्यमियों के लिए आधार बन गई है।
# मैं पारिस्थितिकी संरक्षण संगठन, उनकी पूरी टीम और चंद्रपुर के लोगों को बधाई देता हूं।
# सुरक्षा और रक्षा सहयोग ने हमारे संबंधों में नए आयाम जोड़े हैं।
# भारत और रूस के बीच द्वीपक्षीय संबंध आपसी हित के मुद्दों पर व्यापक समझ से चिह्नित हैं।
# ...

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# Initialize tokenizer, processor, and model
tokenizer = IndicTransTokenizer(direction="indic-en")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-indic-en-dist-200M", trust_remote_code=True)

# Read input sentences from a file in batches
input_file = "benchmarks/benchmarks/wat2021-devtest/dev.en" 
output_file = "indictrans_en.txt"  # Update with the desired output file path

# Define batch size
batch_size = 8

# with open(input_file, "r", encoding="utf-8") as file:
#     sentences = file.readlines()
sentences=random_hi
# Process and translate sentences in batches
with open(output_file, "w", encoding="utf-8") as file:
    for i in range(0, len(sentences), batch_size):
        batch_sentences = sentences[i:i+batch_size]
        
        # Preprocess the batch
        batch = ip.preprocess_batch(batch_sentences, src_lang="hin_Deva", tgt_lang="eng_Latn")
        batch = tokenizer(batch, src=True, return_tensors="pt")

        # Generate translations
        with torch.inference_mode():
            outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

        # Decode and postprocess the translations
        translations = tokenizer.batch_decode(outputs, src=False)
        translations = ip.postprocess_batch(translations, lang="eng_Latn")

        # Write translations to output file
        for translation in translations:
            file.write(translation + "\n")
            print(translation)
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/61.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/914M [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# Initialize tokenizer, processor, and model
tokenizer = IndicTransTokenizer(direction="indic-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-indic-indic-dist-320M", trust_remote_code=True)

# Read input sentences from a file in batches
input_file = "benchmarks/benchmarks/wat2021-devtest/dev.en" 
output_file = "indictrans_mr.txt"  # Update with the desired output file path

# Define batch size
batch_size = 8

# with open(input_file, "r", encoding="utf-8") as file:
#     sentences = file.readlines()
sentences=random_hi
# Process and translate sentences in batches
with open(output_file, "w", encoding="utf-8") as file:
    for i in range(0, len(sentences), batch_size):
        batch_sentences = sentences[i:i+batch_size]
        
        # Preprocess the batch
        batch = ip.preprocess_batch(batch_sentences, src_lang="hin_Deva", tgt_lang="mar_Deva")
        batch = tokenizer(batch, src=True, return_tensors="pt")

        # Generate translations
        with torch.inference_mode():
            outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

        # Decode and postprocess the translations
        translations = tokenizer.batch_decode(outputs, src=False)
        translations = ip.postprocess_batch(translations, lang="mar_Deva")

        # Write translations to output file
        for translation in translations:
            file.write(translation + "\n")
            print(translation)
# Out:
# config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-dist-320M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/61.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-dist-320M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/1.28G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForSeq2SeqLM
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

# Initialize tokenizer, processor, and model
tokenizer = IndicTransTokenizer(direction="indic-indic")
ip = IndicProcessor(inference=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-indic-indic-dist-320M", trust_remote_code=True)

# Read input sentences from a file in batches
input_file = "benchmarks/benchmarks/wat2021-devtest/dev.en" 
output_file = "indictrans_mr_hi.txt"  # Update with the desired output file path

# Define batch size
batch_size = 8

# with open(input_file, "r", encoding="utf-8") as file:
#     sentences = file.readlines()
sentences=random_mr
# Process and translate sentences in batches
with open(output_file, "w", encoding="utf-8") as file:
    for i in range(0, len(sentences), batch_size):
        batch_sentences = sentences[i:i+batch_size]
        
        # Preprocess the batch
        batch = ip.preprocess_batch(batch_sentences, src_lang="mar_Deva", tgt_lang="hin_Deva")
        batch = tokenizer(batch, src=True, return_tensors="pt")

        # Generate translations
        with torch.inference_mode():
            outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

        # Decode and postprocess the translations
        translations = tokenizer.batch_decode(outputs, src=False)
        translations = ip.postprocess_batch(translations, lang="hin_Deva")

        # Write translations to output file
        for translation in translations:
            file.write(translation + "\n")
            print(translation)
# Out:
# इस क्रांति मंदिर में एक चित्रकला संग्रहालय बनाया गया है।
# मंत्रिमंडल ने सेबी और यूरोपीय प्रतिभूति और बाजार प्राधिकरण के बीच आपसी सहयोग पर एक समझौता ज्ञापन को मंजूरी दी है।
# अन्य देशों में ग्राहकों से संबंधित मामलों में तेजी से कार्रवाई करने के लिए सहयोग का एक ढांचा भी तैयार किया जाना चाहिए।
# 2022 तक हमारा लक्ष्य 175 गीगावाट अक्षय ऊर्जा क्षमता का निर्माण करना है।
# आज, "मुद्रा योजना", "स्टार्ट अप इंडिया", "स्टैंड अप इंडिया" जैसे उपक्रम देश में युवा शोधकर्ताओं और युवा उद्यमियों को विकसित कर रहे हैं।
# मैं पारिस्थितिकी संरक्षण संगठन की सभी टीमों और चंद्रपुरवासियों को बधाई और बधाई देता हूं।
# सुरक्षा और रक्षा सहयोग ने हमारे संबंधों को एक नया आयाम प्रदान किया है।
# भारत और रूस के बीच द्विपक्षीय संबंध आपसी हित के मुद्दों पर व्यापक समझौते से प्रेरित हैं।
# यह हमारे ध्यान में आया है कि आतंकवाद, हिंसक उग्रवाद और परिवर्तनवाद के प्रसार को रोकने के लिए तत्काल उपाय करने की आवश्यकता है।
# श्री गुरबचन सिंह जी के परिवार ने हमारे सामने ऐसा ही एक उदाहरण रखा है।
# ...

# %% [markdown]
# Rouge and BLEU scores for en to hi(IndicTrans)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/indictrans/indictrans_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_hi[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.6199829772051133, 'p': 0.6229972577642819, 'f': 0.6196503419213135}, 'rouge-2': {'r': 0.3951203827677216, 'p': 0.3959420927156782, 'f': 0.3941071755175675}, 'rouge-l': {'r': 0.5961579718011607, 'p': 0.5988866561323247, 'f': 0.595822153313835}}
# BLEU Score: 0.6722577519141627

# %% [markdown]
# Rouge and BLEU scores for hi to en(IndicTrans)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/indictrans/indictrans_en.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_en[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_en[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.6258063966213312, 'p': 0.6749461205924392, 'f': 0.6478407053401584}, 'rouge-2': {'r': 0.4260677770881529, 'p': 0.45552599313759606, 'f': 0.4391917528533409}, 'rouge-l': {'r': 0.5950386655601219, 'p': 0.6400665589775834, 'f': 0.615328137550155}}
# BLEU Score: 0.751719837792334

# %% [markdown]
# Rouge and BLEU scores for hi to mr(IndicTrans)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/indictrans/indictrans_mr.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_mr[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_mr[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.40162350772722294, 'p': 0.4320291718085837, 'f': 0.4129994806997695}, 'rouge-2': {'r': 0.17884063322298616, 'p': 0.19646912839482497, 'f': 0.1856174731288472}, 'rouge-l': {'r': 0.3803285196915228, 'p': 0.40907046711458483, 'f': 0.39094647107962976}}
# BLEU Score: 0.6016541253174293

# %% [markdown]
# Rouge and BLEU scores for mr to hi(IndicTrans)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/indictrans/indictrans_mr_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences[:50],random_hi[:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[:50]], candidate_sentences[:50])
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5234262025384318, 'p': 0.540267961518298, 'f': 0.5279061738229235}, 'rouge-2': {'r': 0.2727585016706074, 'p': 0.28163422363520624, 'f': 0.274922145085684}, 'rouge-l': {'r': 0.489632525455281, 'p': 0.5061459161267682, 'f': 0.4942131459134382}}
# BLEU Score: 0.5632465432959229

# %% [markdown]
# Rouge and BLEU scores for hi to en(ChatGPT)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/chatgpt/ChatGPT_en.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences,random_en[0:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_en[0:50]], candidate_sentences)
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.4279686881275049, 'p': 0.4425164326729344, 'f': 0.433004831116422}, 'rouge-2': {'r': 0.27828762813532126, 'p': 0.29643828200267824, 'f': 0.28579873398778294}, 'rouge-l': {'r': 0.4143323429911598, 'p': 0.42847798342008886, 'f': 0.41925479982022834}}
# BLEU Score: 0.6097577869337699

# %% [markdown]
# Rouge and BLEU scores for en to hi(ChatGPT)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/chatgpt/ChatGPT_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences,random_hi[0:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[0:50]], candidate_sentences)
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.5430425913955326, 'p': 0.5453899485148646, 'f': 0.5419347463809353}, 'rouge-2': {'r': 0.2806658936330862, 'p': 0.28124987648790983, 'f': 0.27959549315994037}, 'rouge-l': {'r': 0.5172930328185745, 'p': 0.5186361584751679, 'f': 0.5158361430325032}}
# BLEU Score: 0.6067501817629618

# %% [markdown]
# Rouge and BLEU scores for hi to mr(ChatGPT)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/chatgpt/ChatGPT_mr.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences,random_mr[0:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_mr[0:50]], candidate_sentences)
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.24058577473438147, 'p': 0.26799829346779813, 'f': 0.25161846508624175}, 'rouge-2': {'r': 0.0660132775721011, 'p': 0.07239386920269274, 'f': 0.06839548733860376}, 'rouge-l': {'r': 0.2322582893542645, 'p': 0.25847967319917786, 'f': 0.24274521353195574}}
# BLEU Score: 0.4836747634185947

# %% [markdown]
# Rouge and BLEU scores for mr to hi(ChatGPT)

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# Load reference and candidate sentences from files
def load_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        sentences = [line.strip() for line in f]
    return sentences

# File paths for reference and candidate sentences
# reference_file = 'reference_sentences.txt'
candidate_file = '/kaggle/input/chatgpt/ChatGPT_mr_hi.txt'

# Load sentences from files
# reference_sentences = load_sentences(reference_file)
candidate_sentences = load_sentences(candidate_file)

# Initialize ROUGE
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(candidate_sentences,random_hi[0:50], avg=True)
print("ROUGE Scores:", scores)

# Calculate BLEU score
bleu_score = corpus_bleu([[ref] for ref in random_hi[0:50]], candidate_sentences)
print("BLEU Score:", bleu_score)
# Out:
# ROUGE Scores: {'rouge-1': {'r': 0.503608875988133, 'p': 0.5453656085542612, 'f': 0.5175675914141056}, 'rouge-2': {'r': 0.2713787170024143, 'p': 0.296048535507009, 'f': 0.2794942418838456}, 'rouge-l': {'r': 0.47114945005115283, 'p': 0.5081528211995301, 'f': 0.4832464344476155}}
# BLEU Score: 0.5307377451522823
